# %% [markdown]
# <a href="https://colab.research.google.com/github/jasimuddin365/Master_Generative_Ai/blob/main/1_2_Python_List%2C_Tuples%2C_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Data Structures: Lists, Tuples, and Dictionaries
#
# This tutorial provides an in-depth look at Python's built-in collection types. Understanding these is fundamental to organizing and manipulating data efficiently.
#
# ### Learning Objectives:
# * **Lists**: Creating, indexing, slicing, and modifying ordered collections.
# * **Tuples**: Understanding immutability and common use cases for fixed sequences.
# * **Dictionaries**: Using key-value pairs to store and retrieve structured data.
# * **Operations**: Mastering methods like `append`, `pop`, `get`, and the `in` operator.

# %% [markdown]
# ## List
#
# A list in Python is an ordered collection of values. Lists can hold values of different data types and support operations to add, remove, and change values. Lists have the type `list`.
#
# To create a list, enclose a sequence of values within square brackets `[` and `]`, separated by commas.

# %%
fruits = ['apple', 'banana', 'cherry']

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
type(fruits)
# Out:
# list

# %%
a_list = [23, 'hello', None, 3.14, fruits, 3 <= 5]

# %%
a_list
# Out:
# [23, 'hello', None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
empty_list = []

# %%
empty_list
# Out:
# []

# %% [markdown]
# To determine the number of values in a list, use the `len` function. You can use `len`  to determine the number of values in several other data types.

# %%
len(fruits)
# Out:
# 3

# %%
print("Number of fruits:", len(fruits))
# Out:
# Number of fruits: 3

# %%
len(a_list)
# Out:
# 6

# %%
len(empty_list)
# Out:
# 0

# %% [markdown]
# You can access an element from the list using its *index*, e.g., `fruits[2]` returns the element at index 2 within the list `fruits`. The starting index of a list is 0.

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[1]
# Out:
# 'banana'

# %%
fruits[2]
# Out:
# 'cherry'

# %% [markdown]
# If you try to access an index equal to or higher than the length of the list, Python returns an `IndexError`.

# %%
fruits[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1891/1511222973.py in <cell line: 0>()
# ----> 1 fruits[3]
#
# IndexError: list index out of range

# %% [markdown]
# You can use negative indices to access elements from the end of a list, e.g., `fruits[-1]` returns the last element, `fruits[-2]` returns the second last element, and so on.

# %%
fruits[-1]
# Out:
# 'cherry'

# %%
fruits[-2]
# Out:
# 'banana'

# %%
fruits[-3]
# Out:
# 'apple'

# %%
fruits[-4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1891/4281187226.py in <cell line: 0>()
# ----> 1 fruits[-4]
#
# IndexError: list index out of range

# %% [markdown]
# You can also access a range of values from the list. The result is itself a list. Let us look at some examples.

# %%
another_list = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
another_list
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
another_list[2:5]
# Out:
# ['C', 'D', 'E']

# %% [markdown]
# Note that the range `2:5` includes the element at the start index `2` but does not include the element at the end index `5`. So, the result has 3 values (index `2`, `3`, and `4`).
#
# Here are some experiments you should try out (use the empty cells below):
#
# * Try setting one or both indices of the range are larger than the size of the list, e.g., `another_list[2:10]`
# * Try setting the start index of the range to be larger than the end index, e.g., `another_list[2:10]`
# * Try leaving out the start or end index of a range, e.g., `another_list[2:]` or `another_list[:5]`
# * Try using negative indices for the range, e.g., `another_list[-2:-5]` or `another_list[-5:-2]` (can you explain the results?)
#
# > The flexible and interactive nature of Jupyter notebooks makes them an excellent tool for learning and experimentation. If you are new to Python, you can resolve most questions as soon as they arise simply by typing the code into a cell and executing it. Let your curiosity run wild, discover what Python is capable of and what it isn't!

# %%
another_list[2:10]
# Out:
# ['C', 'D', 'E', 'F', 'G']

# %%
another_list[2:]
# Out:
# ['C', 'D', 'E', 'F', 'G']

# %%
another_list[:5]
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
another_list[-5:-2]
# Out:
# ['C', 'D', 'E']

# %% [markdown]
# You can also change the value at a specific index within a list using the assignment operation.

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits[1] = 'blueberry'

# %%
fruits
# Out:
# ['apple', 'blueberry', 'cherry']

# %% [markdown]
# A new value can be added to the end of a list using the `append` method.

# %%
fruits.append('dates')

# %%
fruits
# Out:
# ['apple', 'blueberry', 'cherry', 'dates']

# %% [markdown]
# A new value can also be inserted at a specific index using the `insert` method.

# %%
fruits.insert(1, 'banana')

# %%
fruits
# Out:
# ['apple', 'banana', 'blueberry', 'cherry', 'dates']

# %% [markdown]
# You can remove a value from a list using the `remove` method.

# %%
fruits.remove('blueberry')

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'dates']

# %% [markdown]
# To remove an element from a specific index, use the `pop` method. The method also returns the removed element.

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'dates']

# %%
fruits.pop()
# Out:
# 'dates'

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['banana', 'cherry']

# %% [markdown]
# You can test whether a list contains a value using the `in` operator.

# %%
'pineapple' in fruits
# Out:
# False

# %%
'cherry' in fruits
# Out:
# True

# %% [markdown]
# To combine two or more lists, use the `+` operator. This operation is also called *concatenation*.

# %%
fruits
# Out:
# ['banana', 'cherry']

# %%
more_fruits = fruits + ['pineapple', 'tomato', 'guava'] + ['dates', 'banana']

# %%
more_fruits
# Out:
# ['banana', 'cherry', 'pineapple', 'tomato', 'guava', 'dates', 'banana']

# %%
more_fruits_copy = more_fruits.copy()

# %%
more_fruits_copy
# Out:
# ['banana', 'cherry', 'pineapple', 'tomato', 'guava', 'dates', 'banana']

# %%
# Modify the copy
more_fruits_copy.remove('pineapple')
more_fruits_copy.pop()
more_fruits_copy
# Out:
# ['banana', 'cherry', 'tomato', 'guava', 'dates']

# %%
# Original list remains unchanged
more_fruits
# Out:
# ['banana', 'cherry', 'pineapple', 'tomato', 'guava', 'dates', 'banana']

# %% [markdown]
# Note that you cannot create a copy of a list by simply creating a new variable using the assignment operator `=`. The new variable will point to the same list, and any modifications performed using either variable will affect the other.

# %%
more_fruits
# Out:
# ['banana', 'cherry', 'pineapple', 'tomato', 'guava', 'dates', 'banana']

# %%
more_fruits_not_a_copy = more_fruits

# %%
more_fruits_not_a_copy.remove('pineapple')
more_fruits_not_a_copy.pop()
# Out:
# 'banana'

# %%
more_fruits_not_a_copy
# Out:
# ['banana', 'cherry', 'tomato', 'guava', 'dates']

# %%
more_fruits
# Out:
# ['banana', 'cherry', 'tomato', 'guava', 'dates']

# %% [markdown]
# ## Tuple
#
# A tuple is an ordered collection of values, similar to a list. However, it is not possible to add, remove, or modify values in a tuple. A tuple is created by enclosing values within parentheses `(` and `)`, separated by commas.
#
# > Any data structure that cannot be modified after creation is called *immutable*. You can think of tuples as immutable lists.
#
# Let's try some experiments with tuples.

# %%
fruits = ('apple', 'cherry', 'dates')

# %%
# check no. of elements
len(fruits)
# Out:
# 3

# %%
# get an element (positive index)
fruits[0]
# Out:
# 'apple'

# %%
# get an element (negative index)
fruits[-2]
# Out:
# 'cherry'

# %%
# check if it contains an element
'dates' in fruits
# Out:
# True

# %%
# try to change an element
fruits[0] = 'avocado'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1891/184743337.py in <cell line: 0>()
#       1 # try to change an element
# ----> 2 fruits[0] = 'avocado'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# You can also skip the parantheses `(` and `)` while creating a tuple. Python automatically converts comma-separated values into a tuple.

# %%
the_3_musketeers = 'Athos', 'Porthos', 'Aramis'

# %%
the_3_musketeers
# Out:
# ('Athos', 'Porthos', 'Aramis')

# %% [markdown]
# You can also create a tuple with just one element by typing a comma after it. Just wrapping it with parentheses `(` and `)` won't make it a tuple.

# %%
single_element_tuple = 4,

# %%
single_element_tuple
# Out:
# (4,)

# %%
another_single_element_tuple = (4,)

# %%
another_single_element_tuple
# Out:
# (4,)

# %%
not_a_tuple = (4)

# %%
not_a_tuple
# Out:
# 4

# %%
type(not_a_tuple)
# Out:
# int

# %% [markdown]
# Tuples are often used to create multiple variables with a single statement.

# %%
point = (3, 4)

# %%
point_x, point_y = point

# %%
point_x
# Out:
# 3

# %% [markdown]
# You can convert a list into a tuple using the `tuple` function, and vice versa using the `list` function

# %%
tuple(['one', 'two', 'three'])
# Out:
# ('one', 'two', 'three')

# %%
list(('Athos', 'Porthos', 'Aramis'))
# Out:
# ['Athos', 'Porthos', 'Aramis']

# %% [markdown]
# ## Dictionary
#
# A dictionary is an unordered collection of items. Each item stored in a dictionary has a key and value. You can use a key to retrieve the corresponding value from the dictionary.  Dictionaries have the type `dict`.
#
# Dictionaries are often used to store many pieces of information e.g. details about a person, in a single variable. Dictionaries are created by enclosing key-value pairs within braces or curly brackets `{` and `}`.

# %%
person1 = {
    'name': 'John Doe',
    'gender': 'Male',
    'age': 32,
    'married': True
}

# %%
person1
# Out:
# {'name': 'John Doe', 'gender': 'Male', 'age': 32, 'married': True}

# %% [markdown]
# Dictionaries can also be created using the `dict` function.

# %%
person2 = dict(name='Jane Judy', gender='Female', age=28, married=False)

# %%
person2
# Out:
# {'name': 'Jane Judy', 'gender': 'Female', 'age': 28, 'married': False}

# %%
type(person1)
# Out:
# dict

# %% [markdown]
# Keys can be used to access values using square brackets `[` and `]`.

# %%
person1['name']
# Out:
# 'John Doe'

# %%
person2['age']
# Out:
# 28

# %% [markdown]
# If a key isn't present in the dictionary, then a `KeyError` is *thrown*.

# %%
person1['address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1891/786906807.py in <cell line: 0>()
# ----> 1 person1['address']
#
# KeyError: 'address'

# %% [markdown]
# You can also use the `get` method to access the value associated with a key.

# %%
person2.get("name")
# Out:
# 'Jane Judy'

# %% [markdown]
# The `get` method also accepts a default value, returned if the key is not present in the dictionary.

# %%
person2.get("address", "Unknown")
# Out:
# 28

# %% [markdown]
# You can check whether a key is present in a dictionary using the `in` operator.

# %%
'name' in person1
# Out:
# True

# %%
'address' in person1
# Out:
# False

# %%
person2['age']
# Out:
# 28

# %%
person2['age'] = 32

# %%
person2['age']
# Out:
# 32

# %%
person2
# Out:
# {'name': 'Jane Judy', 'gender': 'Female', 'age': 32, 'married': False}

# %% [markdown]
# To remove a key and the associated value from a dictionary, use the `pop` method.

# %%
person1
# Out:
# {'name': 'John Doe', 'gender': 'Male', 'age': 32, 'married': True}

# %%
person1.pop('age')
# Out:
# 32

# %%
person1
# Out:
# {'name': 'John Doe', 'gender': 'Male', 'married': True}

# %%
person1.keys()
# Out:
# dict_keys(['name', 'gender', 'married'])

# %%
person1.values()
# Out:
# dict_values(['John Doe', 'Male', True])

# %%
person1.items()
# Out:
# dict_items([('name', 'John Doe'), ('gender', 'Male'), ('married', True)])
